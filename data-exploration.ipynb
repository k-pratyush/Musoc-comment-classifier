# %%
import pandas as pd
import scipy
import numpy as np
import matplotlib.pyplot as plt
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/pratyush/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
train_data = pd.read_csv("train.csv")

# %%
test_data = pd.read_csv("test.csv")

# %%
test_labels = pd.read_csv("test_labels.csv")

# %%
sample_submission = pd.read_csv("sample_submission.csv")

# %%
sample_submission
# Out:
#                       id  toxic  severe_toxic  obscene  threat  insult  \
# 0       00001cee341fdb12    0.5           0.5      0.5     0.5     0.5
# 1       0000247867823ef7    0.5           0.5      0.5     0.5     0.5
# 2       00013b17ad220c46    0.5           0.5      0.5     0.5     0.5
# 3       00017563c3f7919a    0.5           0.5      0.5     0.5     0.5
# 4       00017695ad8997eb    0.5           0.5      0.5     0.5     0.5
# 5       0001ea8717f6de06    0.5           0.5      0.5     0.5     0.5
# 6       00024115d4cbde0f    0.5           0.5      0.5     0.5     0.5
# 7       000247e83dcc1211    0.5           0.5      0.5     0.5     0.5
# 8       00025358d4737918    0.5           0.5      0.5     0.5     0.5
# 9       00026d1092fe71cc    0.5           0.5      0.5     0.5     0.5
# 10      0002eadc3b301559    0.5           0.5      0.5     0.5     0.5
# 11      0002f87b16116a7f    0.5           0.5      0.5     0.5     0.5
# ...

# %%
text_1 = train_data["comment_text"][2]

# %%
tokens = nltk.word_tokenize(test_data["comment_text"][0])

# %%
# Out:
# ['Hey',
#  'man',
#  ',',
#  'I',
#  "'m",
#  'really',
#  'not',
#  'trying',
#  'to',
#  'edit',
#  'war',
#  '.',
#  'It',
#  "'s",
#  'just',
#  'that',
#  'this',
#  'guy',
#  'is',
#  'constantly',
#  'removing',
#  'relevant',
#  'information',
#  'and',
#  'talking',
#  'to',
#  'me',
#  'through',
#  'edits',
#  'instead',
#  'of',
#  'my',
#  'talk',
#  'page',
#  '.',
#  'He',
#  'seems',
#  'to',
#  'care',
#  'more',
#  'about',
#  'the',
#  'formatting',
#  'than',
#  'the',
#  'actual',
#  'info',
#  '.']

# %%
vectorizer = CountVectorizer(stop_words="english", analyzer='word', 
                            ngram_range=(1, 1), max_df=1.0, min_df=1, max_features=None)

# %%
txt = "dhjl dsijof sdf ijo fdso ;KFSD"
txt = [txt]

# %%
count_train_1 = vectorizer.fit_transform(txt)

# %%
count_train_1
# Out:
# <1x6 sparse matrix of type '<type 'numpy.int64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %%
train_words = vectorizer.transform(txt)

# %%
train_words
# Out:
# <1x6 sparse matrix of type '<type 'numpy.int64'>'
# 	with 6 stored elements in Compressed Sparse Row format>

# %%
print(vectorizer.get_feature_names())
# Out:
# [u'dhjl', u'dsijof', u'fdso', u'ijo', u'kfsd', u'sdf']

# %%
label_cols = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']
train_data['none'] = 1-train_data[label_cols].max(axis=1)
train_data.describe()
# Out:
#                toxic   severe_toxic        obscene         threat  \
# count  159571.000000  159571.000000  159571.000000  159571.000000
# mean        0.095844       0.009996       0.052948       0.002996
# std         0.294379       0.099477       0.223931       0.054650
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#               insult  identity_hate           none
# count  159571.000000  159571.000000  159571.000000
# mean        0.049364       0.008805       0.898321
# std         0.216627       0.093420       0.302226
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       1.000000
# 50%         0.000000       0.000000       1.000000
# ...

# %%
COMMENT = 'comment_text'
train_data[COMMENT].fillna("unknown", inplace=True)
test_data[COMMENT].fillna("unknown", inplace=True)

# %%
n = train_data.shape[0]
vec = TfidfVectorizer(ngram_range=(1,2), tokenizer=tokens,
               min_df=3, max_df=0.9, strip_accents='unicode', use_idf=1,
               smooth_idf=1, sublinear_tf=1 )
trn_term_doc = vec.fit_transform(train_data[COMMENT])
test_term_doc = vec.transform(test_data[COMMENT])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-93e102e61d21> in <module>()
#       3                min_df=3, max_df=0.9, strip_accents='unicode', use_idf=1,
#       4                smooth_idf=1, sublinear_tf=1 )
# ----> 5 trn_term_doc = vec.fit_transform(train_data[COMMENT])
#       6 test_term_doc = vec.transform(test_data[COMMENT])
#
# /Users/pratyush/anaconda/envs/gl-env/lib/python2.7/site-packages/sklearn/feature_extraction/text.pyc in fit_transform(self, raw_documents, y)
#    1611         """
#    1612         self._check_params()
# -> 1613         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1614         self._tfidf.fit(X)
#    1615         # X is already a transformed view of raw_documents so
#
# ...
